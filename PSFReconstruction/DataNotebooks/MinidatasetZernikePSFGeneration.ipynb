# %%
from minidataset_constants import NUMPY_SUFFIX, \
                                  PATHS_DICTIONARY

from data_utils import generate_zernike_psf_complex_fields,\
                       generate_psf_complex_fields, \
                       compute_output_fluxes_from_complex_field, \
                       compute_output_fluxes_from_complex_field_using_arbitrary_transfer_matrix, \
                       compute_lp_modes_from_complex_field

# %% [markdown]
# ### Output fluxes

# %%
for dataset_name, ds_info in PATHS_DICTIONARY.items():
    print(f"Generating {dataset_name}")
    psf_path = ds_info["complex_field_path"]
    zernike_coeffs_path = ds_info["zernike_mode_coefficients_path"]
    lp_coeffs_path = ds_info["lp_modes_path"]
    flux_path = ds_info["output_fluxes"]
    n_zernike_modes = len(ds_info["zernike_mode_indexes"])
    coefficients_range = ds_info["zernike_coefficients_range"]
    n_samples = ds_info["n_samples"]
    print(psf_path)
    print(zernike_coeffs_path)
    print(flux_path)
    print(ds_info["zernike_mode_indexes"])
    print(coefficients_range)
    
    print("    Generating PSFs")
    generate_zernike_psf_complex_fields(psf_path,
                                        zernike_coeffs_path,
                                        zernike_modes=n_zernike_modes,
                                        coefficients_range=coefficients_range,
                                        n_samples=n_samples,
                                        overwrite=False)

    print("    Generating Fluxes and LP coefficients")
    compute_output_fluxes_from_complex_field(psf_path,
                                             lp_coeffs_path,
                                             flux_path,
                                             overwrite=False)
# Out:
# Generating MINI_2M
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/PSFReconstructionMinidataset/ZernikeComplexFields/2M_zernike_complex_fields.npy
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/PSFReconstructionMinidataset/ZernikeModeCoefficients/2M_zernike_mode_coefficients.npy
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/PSFReconstructionMinidataset/ZernikeOutputFluxes/2M_zernike_output_fluxes.npy
# [2, 3]
# [[1.8, 2], [1.8, 2]]
#     Generating PSFs
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/PSFReconstructionMinidataset/ZernikeComplexFields/2M_zernike_complex_fields.npy already exists
#     Generating Fluxes and LP coefficients
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/PSFReconstructionMinidataset/ZernikeOutputFluxes/2M_zernike_output_fluxes.npy already exists
# Generating MINI_5M
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/PSFReconstructionMinidataset/ZernikeComplexFields/5M_zernike_complex_fields.npy
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/PSFReconstructionMinidataset/ZernikeModeCoefficients/5M_zernike_mode_coefficients.npy
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/PSFReconstructionMinidataset/ZernikeOutputFluxes/5M_zernike_output_fluxes.npy
# [2, 3, 4, 5, 6]
# [[1.8, 2], [1.8, 2], [0.8, 1], [0.8, 1], [0.8, 1], [0.8, 1]]
#     Generating PSFs
#     Generating Fluxes and LP coefficients
# Computing /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/PSFReconstructionMinidataset/ZernikeOutputFluxes/5M_zernike_output_fluxes.npy
# Total number of unique modes found: 19
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/PLImageReconstruction/Utils/lantern_fiber_utils.py:208: RuntimeWarning: invalid value encountered in divide
#   field_sin = field_sin / np.sqrt(np.sum(field_sin**2))

# %%
from data_utils import generate_psf_complex_fields, compute_output_fluxes_from_complex_field
from psf_constants import PSF_TRAIN_FILE_SUFFIXES, \
                          TRAIN_COMPLEX_FIELDS_PREFIX, \
                          VALIDATION_COMPLEX_FIELDS_PATH, \
                          TEST_COMPLEX_FIELDS_PATH, \
                          TRAIN_OUTPUT_FLUXES_FILE_PREFIX, \
                          VALIDATION_OUTPUT_FLUXES_FILE_PATH, \
                          TEST_OUTPUT_FLUXES_FILE_PATH, \
                          NUMPY_SUFFIX

# %%
#generate_psf_complex_fields('./a3.npy', plot=True, n_samples=1)

# %%
#compute_output_fluxes_from_complex_field('./a3.npy', './a4.npy', plot=True, verbose=True)

# %% [markdown]
# # Generate Train data labels

# %%
for fnumber in TRAIN_FILE_SUFFIXES:
    filepath = f"{TRAIN_COMPLEX_FIELDS_PREFIX}{fnumber}{NUMPY_SUFFIX}"
    generate_psf_complex_fields(filepath)

# %% [markdown]
# # Generate Validation data labels

# %%
generate_psf_complex_fields(VALIDATION_COMPLEX_FIELDS_PATH)

# %% [markdown]
# # Generate Test data labels

# %%
generate_psf_complex_fields(TEST_COMPLEX_FIELDS_PATH)

# %% [markdown]
# # Generate Train data features

# %%
for fnumber in TRAIN_FILE_SUFFIXES:
    complex_fields_filepath = f"{TRAIN_COMPLEX_FIELDS_PREFIX}{fnumber}{NUMPY_SUFFIX}"
    output_fluxes_filepath = f"{TRAIN_OUTPUT_FLUXES_FILE_PREFIX}{fnumber}{NUMPY_SUFFIX}"
    compute_output_fluxes_from_complex_field(complex_fields_filepath, output_fluxes_filepath)
# Out:
# Total number of unique modes found: 19
# Total number of unique modes found: 19
# Total number of unique modes found: 19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 complex_fields_filepath = f"{TRAIN_COMPLEX_FIELDS_PREFIX}{fnumber}{NUMPY_SUFFIX}"
#       3 output_fluxes_filepath = f"{TRAIN_OUTPUT_FLUXES_FILE_PREFIX}{fnumber}{NUMPY_SUFFIX}"
# ----> 4 compute_output_fluxes_from_complex_field(complex_fields_filepath, output_fluxes_filepath)
#
# File ~/DaniProjects/SAIL/PhotonicLanternProjects/PLImageReconstruction/Utils/data_utils.py:836, in compute_output_fluxes_from_complex_field(complex_fields_file_path, output_fluxes_file_path, plot, verbose)
#     833 input_field = input_field[cnt-lantern_fiber.npix:cnt+lantern_fiber.npix, cnt-lantern_fiber.npix:cnt+lantern_fiber.npix]
#     835 lantern_fiber.input_field = input_field
# --> 836 lantern_fiber.plot_injection_field(lantern_fiber.input_field, show_colorbar=False, logI=True, vmin=-3, fignum=50)
#     838 coupling, mode_coupling, mode_coupling_complex = lantern_fiber.calc_injection_multi(
#     839 	mode_field_numbers=modes_to_measure,
#     840 	verbose=verbose,
#    (...)
#     844 	ylim=0.3,
#     845 	return_abspower=True)
#     847 # Now get the complex amplitudes of the PL outputs:
#
# File ~/DaniProjects/SAIL/PhotonicLanternProjects/PLImageReconstruction/Utils/lantern_fiber_utils.py:287, in LanternFiber.plot_injection_field(self, field, fignum, show_colorbar, logI, vmin)
#     285 sz = self.max_r * self.core_radius
#     286 plt.figure(fignum)
# --> 287 plt.clf()
#     288 plt.subplot(211)
#     289 if logI:
#
# File ~/miniconda3/envs/sail-pytorch-env/lib/python3.9/site-packages/matplotlib/pyplot.py:1091, in clf()
#    1089 def clf() -> None:
#    1090     """Clear the current figure."""
# -> 1091     gcf().clear()
#
# File ~/miniconda3/envs/sail-pytorch-env/lib/python3.9/site-packages/matplotlib/figure.py:3127, in Figure.clear(self, keep_observers)
#    3125 def clear(self, keep_observers=False):
#    3126     # docstring inherited
# -> 3127     super().clear(keep_observers=keep_observers)
#    3128     # FigureBase.clear does not clear toolbars, as
#    3129     # only Figure can have toolbars
#    3130     toolbar = self.canvas.toolbar
#
# File ~/miniconda3/envs/sail-pytorch-env/lib/python3.9/site-packages/matplotlib/figure.py:995, in FigureBase.clear(self, keep_observers)
#     992 self.subfigs = []
#     994 for ax in tuple(self.axes):  # Iterate over the copy.
# --> 995     ax.clear()
#     996     self.delaxes(ax)  # Remove ax from self._axstack.
#     998 self.artists = []
#
# File ~/miniconda3/envs/sail-pytorch-env/lib/python3.9/site-packages/matplotlib/axes/_base.py:1388, in _AxesBase.clear(self)
#    1386     self.cla()
#    1387 else:
# -> 1388     self.__clear()
#
# File ~/miniconda3/envs/sail-pytorch-env/lib/python3.9/site-packages/matplotlib/axes/_base.py:1271, in _AxesBase.__clear(self)
#    1268 yaxis_visible = self.yaxis.get_visible()
#    1270 for axis in self._axis_map.values():
# -> 1271     axis.clear()  # Also resets the scale to linear.
#    1272 for spine in self.spines.values():
#    1273     spine._clear()  # Use _clear to not clear Axis again
#
# File ~/miniconda3/envs/sail-pytorch-env/lib/python3.9/site-packages/matplotlib/axis.py:895, in Axis.clear(self)
#     882 def clear(self):
#     883     """
#     884     Clear the axis.
#     885
#    (...)
#     893     - registered callbacks
#     894     """
# --> 895     self.label._reset_visual_defaults()
#     896     # The above resets the label formatting using text rcParams,
#     897     # so we then update the formatting using axes rcParams
#     898     self.label.set_color(mpl.rcParams['axes.labelcolor'])
#
# File ~/miniconda3/envs/sail-pytorch-env/lib/python3.9/site-packages/matplotlib/text.py:175, in Text._reset_visual_defaults(self, text, color, fontproperties, usetex, parse_math, wrap, verticalalignment, horizontalalignment, multialignment, rotation, transform_rotates_text, linespacing, rotation_mode, antialiased)
#     157 def _reset_visual_defaults(
#     158     self,
#     159     text='',
#    (...)
#     172     antialiased=None
#     173 ):
#     174     self.set_text(text)
# --> 175     self.set_color(mpl._val_or_rc(color, "text.color"))
#     176     self.set_fontproperties(fontproperties)
#     177     self.set_usetex(usetex)
#
# KeyboardInterrupt:

# %% [markdown]
# # Generate Validation data features

# %%
compute_output_fluxes_from_complex_field(VALIDATION_COMPLEX_FIELDS_PATH, VALIDATION_OUTPUT_FLUXES_FILE_PATH)

# %% [markdown]
# # Generate Test data features

# %%
compute_output_fluxes_from_complex_field(TEST_COMPLEX_FIELDS_PATH, TEST_OUTPUT_FLUXES_FILE_PATH)

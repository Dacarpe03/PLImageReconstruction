# %%
from nmi_analysis_constants import PATHS_DICTIONARY
from data_utils import save_numpy_array
from plot_utils import plot_clusters_from_labels, \
                       plot_cluster_labels_count, \
                       plot_grid_clusters, \
                       plot_kneighbours,\
                       get_number_of_clusters

from sklearn.cluster import KMeans

import numpy as np

# %%
number_of_clusters = [4, 8, 16, 32, 64, 100, 250, 500, 1000]

data_keys = ["umap_intensities_path",
             "zernike_mode_coefficients_path",
             "lp_modes_path",
             "output_fluxes_path"]

labels_keys = ["complex_fields_labels_path",
                "zernike_mode_coefficients_labels_path",
                "lp_modes_labels_path",
                "output_fluxes_labels_path"]

for n_clusters in number_of_clusters:
    cluster_suffix = f"_{n_clusters}kmeans.npy"
    for key, minidataset_dict in PATHS_DICTIONARY.items():
        print(f"Computing {n_clusters} K-Means cluters for dataset {key}")

        for data_path_key, labels_path_key in zip(data_keys, labels_keys):
            
            print(f"    Computing {data_path_key}")
            data_path = minidataset_dict[data_path_key]
            print(data_path)
            labels_path = minidataset_dict[labels_path_key]

            data = np.load(data_path)
            if data_path_key == "lp_modes_path":
                data = data.reshape(5000, 38)
                
            kmeans = KMeans(n_clusters=n_clusters,
                            n_init=200)
            data_labels = kmeans.fit_predict(data)
            
            complete_labels_path = f"{labels_path}{cluster_suffix}"
            save_numpy_array(data_labels, complete_labels_path, single_precision=False)
# Out:
# Computing 4 K-Means cluters for dataset NMI_ANALYSIS_2M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_2M_zernike_intensities.npy
# ERROR: /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ClusterLabels/labels_2M_zernike_complex_fields.npy4kmeans.npy already exists.
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/2M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/2M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/2M_zernike_output_fluxes.npy
# Computing 4 K-Means cluters for dataset NMI_ANALYSIS_5M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_5M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/5M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/5M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/5M_zernike_output_fluxes.npy
# Computing 4 K-Means cluters for dataset NMI_ANALYSIS_9M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_9M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/9M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/9M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/9M_zernike_output_fluxes.npy
# Computing 4 K-Means cluters for dataset NMI_ANALYSIS_14M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_14M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/14M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/14M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/14M_zernike_output_fluxes.npy
# Computing 4 K-Means cluters for dataset NMI_ANALYSIS_20M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_20M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/20M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/20M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/20M_zernike_output_fluxes.npy
# Computing 8 K-Means cluters for dataset NMI_ANALYSIS_2M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_2M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/2M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/2M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/2M_zernike_output_fluxes.npy
# Computing 8 K-Means cluters for dataset NMI_ANALYSIS_5M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_5M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/5M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/5M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/5M_zernike_output_fluxes.npy
# Computing 8 K-Means cluters for dataset NMI_ANALYSIS_9M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_9M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/9M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/9M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/9M_zernike_output_fluxes.npy
# Computing 8 K-Means cluters for dataset NMI_ANALYSIS_14M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_14M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/14M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/14M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/14M_zernike_output_fluxes.npy
# Computing 8 K-Means cluters for dataset NMI_ANALYSIS_20M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_20M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/20M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/20M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/20M_zernike_output_fluxes.npy
# Computing 16 K-Means cluters for dataset NMI_ANALYSIS_2M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_2M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/2M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/2M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/2M_zernike_output_fluxes.npy
# Computing 16 K-Means cluters for dataset NMI_ANALYSIS_5M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_5M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/5M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/5M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/5M_zernike_output_fluxes.npy
# Computing 16 K-Means cluters for dataset NMI_ANALYSIS_9M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_9M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/9M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/9M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/9M_zernike_output_fluxes.npy
# Computing 16 K-Means cluters for dataset NMI_ANALYSIS_14M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_14M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/14M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/14M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/14M_zernike_output_fluxes.npy
# Computing 16 K-Means cluters for dataset NMI_ANALYSIS_20M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_20M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/20M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/20M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/20M_zernike_output_fluxes.npy
# Computing 32 K-Means cluters for dataset NMI_ANALYSIS_2M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_2M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/2M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/2M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/2M_zernike_output_fluxes.npy
# Computing 32 K-Means cluters for dataset NMI_ANALYSIS_5M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_5M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/5M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/5M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/5M_zernike_output_fluxes.npy
# Computing 32 K-Means cluters for dataset NMI_ANALYSIS_9M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_9M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/9M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/9M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/9M_zernike_output_fluxes.npy
# Computing 32 K-Means cluters for dataset NMI_ANALYSIS_14M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_14M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/14M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/14M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/14M_zernike_output_fluxes.npy
# Computing 32 K-Means cluters for dataset NMI_ANALYSIS_20M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_20M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/20M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/20M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/20M_zernike_output_fluxes.npy
# Computing 64 K-Means cluters for dataset NMI_ANALYSIS_2M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_2M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/2M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/2M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/2M_zernike_output_fluxes.npy
# Computing 64 K-Means cluters for dataset NMI_ANALYSIS_5M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_5M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/5M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/5M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/5M_zernike_output_fluxes.npy
# Computing 64 K-Means cluters for dataset NMI_ANALYSIS_9M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_9M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/9M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/9M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/9M_zernike_output_fluxes.npy
# Computing 64 K-Means cluters for dataset NMI_ANALYSIS_14M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_14M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/14M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/14M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/14M_zernike_output_fluxes.npy
# Computing 64 K-Means cluters for dataset NMI_ANALYSIS_20M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_20M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/20M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/20M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/20M_zernike_output_fluxes.npy
# Computing 100 K-Means cluters for dataset NMI_ANALYSIS_2M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_2M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/2M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/2M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/2M_zernike_output_fluxes.npy
# Computing 100 K-Means cluters for dataset NMI_ANALYSIS_5M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_5M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/5M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/5M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/5M_zernike_output_fluxes.npy
# Computing 100 K-Means cluters for dataset NMI_ANALYSIS_9M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_9M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/9M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/9M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/9M_zernike_output_fluxes.npy
# Computing 100 K-Means cluters for dataset NMI_ANALYSIS_14M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_14M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/14M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/14M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/14M_zernike_output_fluxes.npy
# Computing 100 K-Means cluters for dataset NMI_ANALYSIS_20M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_20M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/20M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/20M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/20M_zernike_output_fluxes.npy
# Computing 250 K-Means cluters for dataset NMI_ANALYSIS_2M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_2M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/2M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/2M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/2M_zernike_output_fluxes.npy
# Computing 250 K-Means cluters for dataset NMI_ANALYSIS_5M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_5M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/5M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/5M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/5M_zernike_output_fluxes.npy
# Computing 250 K-Means cluters for dataset NMI_ANALYSIS_9M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_9M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/9M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/9M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/9M_zernike_output_fluxes.npy
# Computing 250 K-Means cluters for dataset NMI_ANALYSIS_14M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_14M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/14M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/14M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/14M_zernike_output_fluxes.npy
# Computing 250 K-Means cluters for dataset NMI_ANALYSIS_20M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_20M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/20M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/20M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/20M_zernike_output_fluxes.npy
# Computing 500 K-Means cluters for dataset NMI_ANALYSIS_2M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_2M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/2M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/2M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/2M_zernike_output_fluxes.npy
# Computing 500 K-Means cluters for dataset NMI_ANALYSIS_5M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_5M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/5M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/5M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/5M_zernike_output_fluxes.npy
# Computing 500 K-Means cluters for dataset NMI_ANALYSIS_9M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_9M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/9M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/9M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/9M_zernike_output_fluxes.npy
# Computing 500 K-Means cluters for dataset NMI_ANALYSIS_14M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_14M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/14M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/14M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/14M_zernike_output_fluxes.npy
# Computing 500 K-Means cluters for dataset NMI_ANALYSIS_20M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_20M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/20M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/20M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/20M_zernike_output_fluxes.npy
# Computing 1000 K-Means cluters for dataset NMI_ANALYSIS_2M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_2M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/2M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/2M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/2M_zernike_output_fluxes.npy
# Computing 1000 K-Means cluters for dataset NMI_ANALYSIS_5M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_5M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/5M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/5M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/5M_zernike_output_fluxes.npy
# Computing 1000 K-Means cluters for dataset NMI_ANALYSIS_9M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_9M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/9M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/9M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/9M_zernike_output_fluxes.npy
# Computing 1000 K-Means cluters for dataset NMI_ANALYSIS_14M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_14M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/14M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/14M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/14M_zernike_output_fluxes.npy
# Computing 1000 K-Means cluters for dataset NMI_ANALYSIS_20M
#     Computing umap_intensities_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ProcessedZernikeComplexFields/umap_20M_zernike_intensities.npy
#     Computing zernike_mode_coefficients_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeModeCoefficients/20M_zernike_mode_coefficients.npy
#     Computing lp_modes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/LPModesFromZernikePSF/20M_lp_modes_from_zernike_psf.npy
#     Computing output_fluxes_path
# /home/dani/DaniProjects/SAIL/PhotonicLanternProjects/Data/NMIAnalysisDatasets/ZernikeOutputFluxes/20M_zernike_output_fluxes.npy
